# %%
import langchain
from langchain_core import __version__ as core_version

print(f"LangChain version: {langchain.__version__}")
print(f"LangChain Core version: {core_version}")

if langchain.__version__ >= "1.0" :
    print("LangChain is up to date!")
else :
    print("Please update LangChain to the latest version.")
# Out:
# LangChain version: 1.2.0
# LangChain Core version: 1.2.6
# LangChain is up to date!

# %%
from dotenv import load_dotenv
import os
#used for loading api key from .env files
load_dotenv()

if os.getenv("GEMMINI_API_KEY"):
    print("SUCCESS: API KEY LOADED")
else:
    print("ERROR: API KEY NOT LOADED")
# Out:
# SUCCESS: API KEY LOADED

# %%
# ...existing code...
from langchain_core.documents import Document

doc = Document(
    page_content="Ayush is learning rag and in next 4 months i will be putthing more than 8-9 hours a day",
    metadata={
        "source": "family happiness",
        "author": "Ayush Singh",
        "date": "01-01-2026",
    }
)

print("content")
print(doc.page_content)
print("\nMetadata:")
print(doc.metadata)
# ...existing code...
# Out:
# content
# Ayush is learning rag and in next 4 months i will be putthing more than 8-9 hours a day
#
# Metadata:
# {'source': 'family happiness', 'author': 'Ayush Singh', 'date': '01-01-2026'}

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature = 0,
    api_key=os.getenv("GOOGLE_API_KEY")
)
result = llm.invoke("who is the ceo of google ai project, give me in words.")
print(result.content)
# Out:
# Google doesn't have a single "CEO of Google AI Project" because AI is integrated across many of its products and research divisions.
#
# However, the overall CEO of Google (and its parent company Alphabet), who ultimately oversees all AI initiatives, is **Sundar Pichai**.
#
# For the specific advanced AI research and development division, **Demis Hassabis** is the CEO of Google DeepMind, which is a major part of Google's AI efforts.

# %% [markdown]
# import function

# %%
# Standard library imports
import os
from pathlib import Path

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# Environment variable management
from dotenv import load_dotenv
load_dotenv()

# LangChain Document Loaders
from langchain_community.document_loaders import PyPDFLoader

# LangChain Text Splitters
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Google Gemini Integration (LLM + Embeddings)
from langchain_google_genai import (
    ChatGoogleGenerativeAI,
    GoogleGenerativeAIEmbeddings
)

# Vector Store - FAISS
from langchain_community.vectorstores import FAISS

# LangChain Core Components
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

print("✓ All imports successful!")
print("✓ Using Google Gemini with LangChain 1.0+")
# Out:
# ✓ All imports successful!
# ✓ Using Google Gemini with LangChain 1.0+

# %%
pdf_path = "attention.pdf"
loader = PyPDFLoader(pdf_path)
doc = loader.load()
print(f"Loaded {len(doc)}")
print(doc[0].page_content[:100])
print(doc[0].metadata)
# Out:
# Loaded 15
# Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and
# {'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=10,
    length_function=len,
    separators=["\n\n", "\n", " ", ""]
)
chunk = text_splitter.split_documents(doc)
print(f"Number of chunks: {len(chunk)}")
print(chunk[4].page_content)
# Out:
# Number of chunks: 542
# Google Research
# usz@google.com
# Llion Jones∗
# Google Research
# llion@google.com
# Aidan N. Gomez∗ †

# %%
from langchain_core.prompts import ChatPromptTemplate

chat = ChatPromptTemplate.from_messages([
    ("system", "You are a professional {profession}"),
    ("human", "Explain this topic: {topic}")
])

messages = chat.format_messages(
    profession="doctor",
    topic="heart"
)

import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash",
)
result = llm.invoke(messages)
print(result.content)
# Out:
# As a professional doctor, I'd be delighted to explain the heart to you. It's one of the most fascinating and vital organs in the human body.
#
# ---
#
# ### The Heart: Your Body's Indefatigable Engine
#
# Imagine a tireless, muscular pump that starts working before you're even born and doesn't stop until your last breath. That's your heart. It's arguably the most critical organ, responsible for circulating blood throughout your entire body, delivering life-sustaining oxygen and nutrients to every cell, and removing waste products.
#
# Let's break down this remarkable organ:
#
# ---
#
# #### 1. Location and Size
#
# *   **Location:** Your heart is situated in the center of your chest, slightly to the left, nestled between your lungs and behind your breastbone (sternum). It's protected by your rib cage.
# *   **Size:** It's roughly the size of your clenched fist, typically weighing between 7 to 15 ounces (200 to 425 grams).
#
# ---
#
# #### 2. Anatomy: The Four Chambers
#
# The heart is essentially a four-chambered muscular organ, divided into two halves (right and left) by a wall called the **septum**. Each half has an upper chamber and a lower chamber:
#
# *   **Atria (Upper Chambers):** These are the receiving chambers.
#     *   **Right Atrium:** Receives deoxygenated (oxygen-poor) blood from the body.
#     *   **Left Atrium:** Receives oxygenated (oxygen-rich) blood from the lungs.
# *   **Ventricles (Lower Chambers):** These are the powerful pumping chambers.
#     *   **Right Ventricle:** Pumps deoxygenated blood to the lungs.
#     *   **Left Ventricle:** Pumps oxygenated blood to the rest of the body. This is the strongest chamber, responsible for the high pressure needed to reach all extremities.
#
# ---
#
# #### 3. The Valves: One-Way Doors
#
# Between each atrium and ventricle, and at the exit of each ventricle, are **four one-way valves**. These valves act like gates, ensuring blood flows in the correct direction and preventing backflow.
#
# *   **Tricuspid Valve:** Between the right atrium and right ventricle.
# *   **Pulmonary Valve:** Between the right ventricle and the pulmonary artery (leading to the lungs).
# *   **Mitral Valve (Bicuspid Valve):** Between the left atrium and left ventricle.
# *   **Aortic Valve:** Between the left ventricle and the aorta (the main artery leading to the body).
#
# The characteristic "lub-dub" sound of your heartbeat is the sound of these valves closing.
#
# ---
#
# #### 4. The Blood Vessels: Highways of Life
#
# While not technically *part* of the heart, the major blood vessels are intimately connected to its function:
#
# *   **Arteries:** Carry blood *away* from the heart. The **aorta** is the largest artery.
# *   **Veins:** Carry blood *towards* the heart. The **vena cavae** (superior and inferior) are the largest veins.
# *   **Capillaries:** Tiny vessels where oxygen, nutrients, and waste exchange occurs between blood and tissues.
#
# ---
#
# #### 5. How It Works: The Pumping Cycle (Cardiac Cycle)
#
# The heart works in a continuous, rhythmic cycle, typically beating 60-100 times per minute, day and night:
#
# 1.  **Diastole (Relaxation/Filling):** The heart muscle relaxes, and the atria fill with blood.
#     *   The right atrium receives deoxygenated blood from the body via the vena cavae.
#     *   The left atrium receives oxygenated blood from the lungs via the pulmonary veins.
# 2.  **Systole (Contraction/Pumping):**
#     *   The atria contract, pushing blood into their respective ventricles.
#     *   The ventricles then contract forcefully.
#     *   The right ventricle pumps deoxygenated blood into the **pulmonary artery** to travel to the lungs.
#     *   The left ventricle pumps oxygenated blood into the **aorta** to be distributed throughout the body.
#
# ---
#
# #### 6. The Electrical System: The Heart's Natural Pacemaker
#
# The heart's rhythmic beating is controlled by its own internal electrical system.
#
# *   **Sinoatrial (SA) Node:** Located in the right atrium, this is the heart's natural "pacemaker." It generates electrical impulses that spread across the atria, causing them to contract.
# *   **Atrioventricular (AV) Node:** These impulses then travel to the AV node, located between the atria and ventricles. The AV node briefly delays the signal, allowing the ventricles to fill completely.
# *   **Purkinje Fibers:** From the AV node, the impulses rapidly spread through specialized fibers (Bundle of His and Purkinje fibers) throughout the ventricles, causing them to contract in a coordinated fashion, pushing blood out.
#
# This precise electrical coordination ensures efficient pumping.
#
# ---
#
# #### 7. The Two Circulations
#
# The heart powers two distinct circulatory systems:
#
# 1.  **Pulmonary Circulation:** The right side of the heart pumps deoxygenated blood to the lungs, where it picks up oxygen and releases carbon dioxide. This newly oxygenated blood then returns to the left side of the heart.
# 2.  **Systemic Circulation:** The left side of the heart pumps this oxygen-rich blood out to the rest of the body (brain, muscles, organs, etc.) through the arteries. After delivering oxygen and nutrients and picking up waste, the deoxygenated blood returns to the right side of the heart via the veins to start the cycle again.
#
# ---
#
# #### 8. Why Your Heart Matters So Much
#
# Every cell in your body needs a continuous supply of oxygen and nutrients to survive and function. Without the heart's constant pumping action, this supply would cease, leading to cell death, organ failure, and ultimately, the cessation of life. It's truly the central engine of your physiological existence.
#
# ---
#
# #### 9. Keeping Your Heart Healthy
#
# Given its critical role, maintaining heart health is paramount. Key strategies include:
#
# *   **Balanced Diet:** Rich in fruits, vegetables, whole grains, lean proteins, and healthy fats; low in saturated/trans fats, cholesterol, sodium, and added sugars.
# *   **Regular Exercise:** At least 150 minutes of moderate-intensity aerobic activity or 75 minutes of vigorous activity per week.
# *   **Maintain a Healthy Weight:** Obesity significantly increases the risk of heart disease.
# *   **Avoid Smoking:** Smoking is one of the biggest risk factors for heart disease.
# *   **Manage Stress:** Chronic stress can negatively impact heart health.
# *   **Limit Alcohol Intake:** Excessive alcohol can damage the heart.
# *   **Regular Check-ups:** Monitor blood pressure, cholesterol, and blood sugar levels.
# *   **Manage Underlying Conditions:** Effectively treat high blood pressure, diabetes, and high cholesterol.
#
# ---
#
# In summary, the heart is an incredibly complex, powerful, and efficient organ that works ceaselessly to sustain life. Understanding its structure and function empowers you to make choices that will keep this vital engine running smoothly for years to come.
