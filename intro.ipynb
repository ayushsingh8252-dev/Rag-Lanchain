# %%
import langchain
from langchain_core import __version__ as core_version

print(f"LangChain version: {langchain.__version__}")
print(f"LangChain Core version: {core_version}")

if langchain.__version__ >= "1.0" :
    print("LangChain is up to date!")
else :
    print("Please update LangChain to the latest version.")
# Out:
# LangChain version: 1.2.0
# LangChain Core version: 1.2.6
# LangChain is up to date!

# %%
from dotenv import load_dotenv
import os
#used for loading api key from .env files
load_dotenv()

if os.getenv("GEMMINI_API_KEY"):
    print("SUCCESS: API KEY LOADED")
else:
    print("ERROR: API KEY NOT LOADED")
# Out:
# SUCCESS: API KEY LOADED

# %%
# ...existing code...
from langchain_core.documents import Document

doc = Document(
    page_content="Ayush is learning rag and in next 4 months i will be putthing more than 8-9 hours a day",
    metadata={
        "source": "family happiness",
        "author": "Ayush Singh",
        "date": "01-01-2026",
    }
)

print("content")
print(doc.page_content)
print("\nMetadata:")
print(doc.metadata)
# ...existing code...
# Out:
# content
# Ayush is learning rag and in next 4 months i will be putthing more than 8-9 hours a day
#
# Metadata:
# {'source': 'family happiness', 'author': 'Ayush Singh', 'date': '01-01-2026'}

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature = 0,
    api_key=os.getenv("GOOGLE_API_KEY")
)
result = llm.invoke("who is the ceo of google ai project, give me in words.")
print(result.content)
# Out:
# The theory of relativity, developed by Albert Einstein, isn't just one idea, but two interconnected theories: **Special Relativity** (1905) and **General Relativity** (1915).
#
# At its heart, relativity tells us that **space and time are not absolute and fixed backdrops** against which events happen. Instead, they are dynamic and interconnected, influenced by motion and gravity.
#
# Let's break it down simply:
#
# ---
#
# ### 1. The "Relative" Part: Frames of Reference
#
# Imagine you're on a train moving at a constant speed.
# *   If you walk down the aisle, your speed relative to the train is, say, 3 mph.
# *   But to someone standing on the ground watching the train go by, your speed is 3 mph *plus* the speed of the train.
#
# This is a "frame of reference." What you observe depends on your own motion. This idea isn't new, but Einstein took it to a revolutionary level.
#
# ---
#
# ### 2. Special Relativity (SR): The Rules for Constant Motion
#
# Special Relativity deals with objects moving at **constant speeds** (no acceleration) and has two main principles:
#
# *   **Principle 1: The Laws of Physics are the Same for Everyone.**
#     No matter how fast you're moving at a constant speed, the laws of physics (like gravity, electromagnetism, etc.) work exactly the same way for you. There's no "special" frame of reference.
#
# *   **Principle 2: The Speed of Light is Constant for Everyone.**
#     This is the mind-bending one. No matter how fast you're moving, or in what direction, if you measure the speed of light in a vacuum, you will *always* get the same answer: about 186,000 miles per second (300,000 km/s).
#
#     Think about it: If you're in a spaceship flying towards a light beam at half the speed of light, you'd expect the light to appear to be moving slower relative to you. But it doesn't! It still zips past you at its full speed.
#
# **What are the consequences of the constant speed of light?**
#
# Because the speed of light is constant for all observers, something else has to give. That "something else" is our everyday understanding of space and time:
#
# *   **Time Dilation (Time Slows Down):**
#     If you're moving very fast relative to someone else, your clock will tick slower than theirs. From your perspective, their clock is ticking slower. This isn't just a trick of perception; it's a real physical effect.
#     *   *Example:* Astronauts on the International Space Station age ever so slightly slower than people on Earth because they're moving so fast.
#
# *   **Length Contraction (Objects Get Shorter):**
#     Objects moving very fast appear to get shorter in the direction of their motion, as observed by someone not moving with them.
#
# *   **Mass-Energy Equivalence (E=mc²):**
#     This is the most famous equation! It tells us that mass and energy are two forms of the same thing. A tiny bit of mass can be converted into a huge amount of energy (that's how nuclear bombs and nuclear power plants work, and how the sun shines).
#     *   **E** = Energy
#     *   **m** = Mass
#     *   **c²** = The speed of light squared (a very, very big number)
#
# **In short, Special Relativity says:** Space and time are not absolute; they are relative to your motion. The faster you move, the slower time passes for you and the shorter you become in the direction of motion, all because the speed of light must remain constant for everyone.
#
# ---
#
# ### 3. General Relativity (GR): Gravity as Spacetime Curvature
#
# General Relativity came 10 years later and brought **gravity** into the picture, dealing with **acceleration** and massive objects.
#
# *   **Einstein's Big Idea: Gravity is Not a Force, It's the Curvature of Spacetime.**
#     Forget the idea of gravity as an invisible force pulling things down. Einstein proposed a revolutionary concept:
#     *   Imagine space and time are woven together into a single, flexible fabric called **spacetime**.
#     *   Massive objects (like planets, stars, black holes) create **dents or curves in this fabric**.
#     *   Other objects (like smaller planets, asteroids, or even light) don't "fall" towards the massive object; they simply follow the curves in spacetime created by it.
#
#     *   *Analogy:* Think of a bowling ball placed on a stretched rubber sheet (spacetime). The bowling ball creates a dip. If you roll a marble nearby, it won't roll in a straight line; it will curve inwards towards the bowling ball, not because the bowling ball is "pulling" it, but because it's following the curve in the sheet.
#
# **What are the consequences of gravity as spacetime curvature?**
#
# *   **Gravitational Time Dilation:**
#     Time runs slower in stronger gravitational fields. The closer you are to a massive object, the slower time passes for you.
#     *   *Example:* Clocks on Earth run slightly slower than clocks on GPS satellites (which are further away from Earth's gravity). GPS systems have to account for both Special and General Relativity to work accurately!
#
# *   **Light Bending:**
#     Since light also follows the curves in spacetime, it will bend around massive objects. This was famously observed during a solar eclipse, proving Einstein right.
#
# *   **Black Holes:**
#     These are regions where spacetime is curved so extremely (due to immense mass packed into a tiny space) that nothing, not even light, can escape.
#
# *   **Expanding Universe:**
#     General Relativity's equations also predicted that the universe itself is expanding.
#
# ---
#
# ### In a Nutshell:
#
# *   **Relativity** means that measurements of space and time are not absolute but depend on the observer's motion and gravitational environment.
# *   **Special Relativity** (constant motion) tells us that the speed of light is constant for everyone, leading to time dilation, length contraction, and E=mc².
# *   **General Relativity** (gravity and acceleration) tells us that gravity isn't a force, but the result of massive objects warping the fabric of spacetime, which then dictates how other objects move.
#
# It's a complex theory, but its core message is that our universe is far more dynamic and interconnected than we intuitively perceive!
